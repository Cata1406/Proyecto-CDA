# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 500)

# %%
info_matriculados = pd.read_parquet("Info_Matriculados_Anon.parquet")
info_matriculados
# Out:
#        PERIODO MATRICULADO_PERIODO_ACTUAL  EDAD TIPO_ESTADO_CIVIL
# 0       201720                         SI  46.0           SOLTERO  \
# 1       201720                         SI  44.0           SOLTERO
# 2       201720                         SI  39.0            CASADO
# 3       202210                         SI  29.0              None
# 4       201720                         SI  49.0        DIVORCIADO
# ...        ...                        ...   ...               ...
# 162620  200919                         SI  43.0           SOLTERO
# 162621  201015                         SI  46.0            CASADO
# 162622  201020                         SI  39.0            CASADO
# 162623  201019                         SI  45.0           SOLTERO
# 162624  200919                         SI  50.0           SOLTERO
#
#        NACIONALIDAD CODIGO_NIVEL_PROGRAMA_1 NIVEL_PROGRAMA_1
# 0        COLOMBIANO                      MA         MAGISTER  \
# 1        COLOMBIANO                      MA         MAGISTER
# 2        COLOMBIANO                      MA         MAGISTER
# 3        COLOMBIANO                      MA         MAGISTER
# 4        COLOMBIANO                      MA         MAGISTER
# ...             ...                     ...              ...
# 162620   No Informa                      MA         MAGISTER
# 162621   COLOMBIANO                      MA         MAGISTER
# 162622   COLOMBIANO                      MA         MAGISTER
# 162623   No Informa                      MA         MAGISTER
# 162624   COLOMBIANO                      MA         MAGISTER
#
#        CODIGO_FACULTAD_PROGRAMA_1 FACULTAD_PROGRAMA_1
# 0                              CD               CIDER  \
# 1                              HU   CIENCIAS SOCIALES
# 2                              AD      ADMINISTRACIÓN
# 3                              IN          INGENIERÍA
# 4                              ED           EDUCACIÓN
# ...                           ...                 ...
# 162620                         AD      ADMINISTRACIÓN
# 162621                         AD      ADMINISTRACIÓN
# 162622                         EC            ECONOMÍA
# 162623                         AD      ADMINISTRACIÓN
# 162624                         IN          INGENIERÍA
#
#        CODIGO_DEPARTAMENTO_PROGRAMA_1         DEPARTAMENTO_PROGRAMA_1
# 0                                CIDE  CENTRO INTERD.ESTUDIOS DESARR.  \
# 1                                CPOL                CIENCIA POLITICA
# 2                                ADMI                  ADMINISTRACION
# 3                                IIND           INGENIERIA INDUSTRIAL
# 4                                CIFE  CENTRO INVESTIG.FORMAC.EDUCAC.
# ...                               ...                             ...
# 162620                           ADMI                  ADMINISTRACION
# 162621                           ADMI                  ADMINISTRACION
# 162622                           ECON                        ECONOMIA
# 162623                           ADMI                  ADMINISTRACION
# 162624                           IELE  INGEN. ELECTRICA Y ELECTRONICA
#
#        CODIGO_PROGRAMA_1                      PROGRAMA_1
# 0                 M-EDES  MAESTRIA EN ESTUD.INTER.DESARR  \
# 1                 M-CPOL    MAESTRIA EN CIENCIA POLITICA
# 2                 M-MBAT  MAESTRIA ADMINISTRACION-MBA-TC
# 3                 M-IIND      MAESTRIA EN ING.INDUSTRIAL
# 4                 M-EDUC           MAESTRIA EN EDUCACION
# ...                  ...                             ...
# 162620            M-MATP      MAESTRIA EN ADMINISTRACION
# 162621            M-MERC            MAESTRIA EN MERCADEO
# 162622            M-ECON            MAESTRIA EN ECONOMIA
# 162623            M-MERC            MAESTRIA EN MERCADEO
# 162624            M-MIEL   MAEST INGENIER.AREA ELECTRICA
#
#        CODIGO_NIVEL_PROGRAMA_2 NIVEL_PROGRAMA_2 CODIGO_FACULTAD_PROGRAMA_2
# 0                                          None                             \
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
# ...                        ...              ...                        ...
# 162620                                     None
# 162621                                     None
# 162622                                     None
# 162623                                     None
# 162624                                     None
#
#        FACULTAD_PROGRAMA_2 CODIGO_DEPARTAMENTO_PROGRAMA_2
# 0                     None                                 \
# 1                     None
# 2                     None
# 3                     None
# 4                     None
# ...                    ...                            ...
# 162620                None
# 162621                None
# 162622                None
# 162623                None
# 162624                None
#
#        DEPARTAMENTO_PROGRAMA_2 CODIGO_PROGRAMA_2 PROGRAMA_2
# 0                         None                         None  \
# 1                         None                         None
# 2                         None                         None
# 3                         None                         None
# 4                         None                         None
# ...                        ...               ...        ...
# 162620                    None                         None
# 162621                    None                         None
# 162622                    None                         None
# 162623                    None                         None
# 162624                    None                         None
#
#        CODIGO_NIVEL_PROGRAMA_3 NIVEL_PROGRAMA_3 CODIGO_FACULTAD_PROGRAMA_3
# 0                                          None                             \
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
# ...                        ...              ...                        ...
# 162620                                     None
# 162621                                     None
# 162622                                     None
# 162623                                     None
# 162624                                     None
#
#        FACULTAD_PROGRAMA_3 CODIGO_DEPARTAMENTO_PROGRAMA_3
# 0                     None                                 \
# 1                     None
# 2                     None
# 3                     None
# 4                     None
# ...                    ...                            ...
# 162620                None
# 162621                None
# 162622                None
# 162623                None
# 162624                None
#
#        DEPARTAMENTO_PROGRAMA_3 CODIGO_PROGRAMA_3 PROGRAMA_3
# 0                         None                         None  \
# 1                         None                         None
# 2                         None                         None
# 3                         None                         None
# 4                         None                         None
# ...                        ...               ...        ...
# 162620                    None                         None
# 162621                    None                         None
# 162622                    None                         None
# 162623                    None                         None
# 162624                    None                         None
#
#             DESC_ESTADO_ACADEMICO CODIGO_ESTUDIANTE_ANON
# 0                          NORMAL             db195bc7d5
# 1                       REINTEGRO             d708c0c540
# 2                          NORMAL             234b8b064c
# 3                          NORMAL             11c8bf67b0
# 4                          NORMAL             16b83d214d
# ...                           ...                    ...
# 162620                     NORMAL             0e25072988
# 162621  PRIMER SEMESTRE POSTGRADO             9ae9134098
# 162622                     NORMAL             580f1c03a2
# 162623                     NORMAL             c49f4a2427
# 162624                  REINTEGRO             bd76685ce9
#
# [162625 rows x 31 columns]

# %%
info_matriculados["MATRICULADO_PERIODO_ACTUAL"].unique()
# Out:
# array(['SI'], dtype=object)

# %% [markdown]
# Decisión: Solo primer programa!

# %%
info_matriculados = info_matriculados[["PERIODO", "CODIGO_ESTUDIANTE_ANON", "EDAD", "TIPO_ESTADO_CIVIL", "NIVEL_PROGRAMA_1", "FACULTAD_PROGRAMA_1", "DEPARTAMENTO_PROGRAMA_1", "PROGRAMA_1", "DESC_ESTADO_ACADEMICO"]]
info_matriculados
# Out:
#        PERIODO CODIGO_ESTUDIANTE_ANON  EDAD TIPO_ESTADO_CIVIL
# 0       201720             db195bc7d5  46.0           SOLTERO  \
# 1       201720             d708c0c540  44.0           SOLTERO
# 2       201720             234b8b064c  39.0            CASADO
# 3       202210             11c8bf67b0  29.0              None
# 4       201720             16b83d214d  49.0        DIVORCIADO
# ...        ...                    ...   ...               ...
# 162620  200919             0e25072988  43.0           SOLTERO
# 162621  201015             9ae9134098  46.0            CASADO
# 162622  201020             580f1c03a2  39.0            CASADO
# 162623  201019             c49f4a2427  45.0           SOLTERO
# 162624  200919             bd76685ce9  50.0           SOLTERO
#
#        NIVEL_PROGRAMA_1 FACULTAD_PROGRAMA_1         DEPARTAMENTO_PROGRAMA_1
# 0              MAGISTER               CIDER  CENTRO INTERD.ESTUDIOS DESARR.  \
# 1              MAGISTER   CIENCIAS SOCIALES                CIENCIA POLITICA
# 2              MAGISTER      ADMINISTRACIÓN                  ADMINISTRACION
# 3              MAGISTER          INGENIERÍA           INGENIERIA INDUSTRIAL
# 4              MAGISTER           EDUCACIÓN  CENTRO INVESTIG.FORMAC.EDUCAC.
# ...                 ...                 ...                             ...
# 162620         MAGISTER      ADMINISTRACIÓN                  ADMINISTRACION
# 162621         MAGISTER      ADMINISTRACIÓN                  ADMINISTRACION
# 162622         MAGISTER            ECONOMÍA                        ECONOMIA
# 162623         MAGISTER      ADMINISTRACIÓN                  ADMINISTRACION
# 162624         MAGISTER          INGENIERÍA  INGEN. ELECTRICA Y ELECTRONICA
#
#                             PROGRAMA_1      DESC_ESTADO_ACADEMICO
# 0       MAESTRIA EN ESTUD.INTER.DESARR                     NORMAL
# 1         MAESTRIA EN CIENCIA POLITICA                  REINTEGRO
# 2       MAESTRIA ADMINISTRACION-MBA-TC                     NORMAL
# 3           MAESTRIA EN ING.INDUSTRIAL                     NORMAL
# 4                MAESTRIA EN EDUCACION                     NORMAL
# ...                                ...                        ...
# 162620      MAESTRIA EN ADMINISTRACION                     NORMAL
# 162621            MAESTRIA EN MERCADEO  PRIMER SEMESTRE POSTGRADO
# 162622            MAESTRIA EN ECONOMIA                     NORMAL
# 162623            MAESTRIA EN MERCADEO                     NORMAL
# 162624   MAEST INGENIER.AREA ELECTRICA                  REINTEGRO
#
# [162625 rows x 9 columns]

# %%
info_matriculados["DESC_ESTADO_ACADEMICO"].unique()
# Out:
# array(['NORMAL', 'PRUEBA ACADEMICA', 'NORMAL POST - REGL 2009',
#        'REINGRESO POSTGRADO', 'REINTEGRO', 'PRIMER SEMESTRE POSTGRADO',
#        'NORMAL DOCTORADO-REG-201120', None, 'PRUEBA DE TRANSFERENCIA',
#        'SUSPENSION', 'PRIMER SEMESTRE DOCTORADO',
#        'REINTEGRO POSTGRADO - SUSP ANT', 'PRUEBA REINGRESO',
#        'EXCLUIDO DEL PROGRAMA-POSTGRAD', 'TEMPORAL- REINGR.O NOTA PEND',
#        'REINTEGRO-NVO PROGRAMA PREGRAD', 'PRUEBA ACADEM.TRANSITORIA 2020',
#        'MA-ES - PGA < 3.00-REGL 202120', 'PRUEBA ACAD.DOC.(EXAM-R-2011)'],
#       dtype=object)

# %%
info_matriculados = info_matriculados[info_matriculados["PERIODO"].astype(int) >= 201500]

# %%
info_matriculados = info_matriculados[info_matriculados["NIVEL_PROGRAMA_1"] == "MAGISTER"]

# %%
info_matriculados[info_matriculados.duplicated(subset = ["CODIGO_ESTUDIANTE_ANON", "PERIODO"])]
# Out:
# Empty DataFrame
# Columns: [PERIODO, CODIGO_ESTUDIANTE_ANON, EDAD, TIPO_ESTADO_CIVIL, NIVEL_PROGRAMA_1, FACULTAD_PROGRAMA_1, DEPARTAMENTO_PROGRAMA_1, PROGRAMA_1, DESC_ESTADO_ACADEMICO]
# Index: []

# %%
ha = pd.read_parquet("Historia_Academica_Anon.parquet")
ha
# Out:
#        PERIODO CODIGO_NIVEL_PROGRAMA DESCRIPCION_NIVEL_PROGRAMA  SSC
# 0       196820                    MA                   MAGISTER  0.0  \
# 1       196910                    MA                   MAGISTER  0.0
# 2       197019                    MA                   MAGISTER  0.0
# 3       196919                    MA                   MAGISTER  0.0
# 4       197020                    MA                   MAGISTER  0.0
# ...        ...                   ...                        ...  ...
# 175857  202419                    MA                   MAGISTER  0.0
# 175858  202419                    MA                   MAGISTER  0.0
# 175859  202419                    MA                   MAGISTER  0.0
# 175860  202419                    MA                   MAGISTER  0.0
# 175861  202419                    MA                   MAGISTER  0.0
#
#         CREDITO_SEM_INTENTADO_INSTITUCIONAL
# 0                                       7.0  \
# 1                                      10.0
# 2                                       5.0
# 3                                       2.0
# 4                                      16.0
# ...                                     ...
# 175857                                  2.0
# 175858                                  0.0
# 175859                                  2.0
# 175860                                  0.0
# 175861                                  0.0
#
#         CREDITO_SEM_APROBADO_INSTITUCIONAL  PROMEDIO_SEM_GLOBAL
# 0                                      5.0                 2.92  \
# 1                                     10.0                 3.40
# 2                                      5.0                 5.00
# 3                                      2.0                 4.50
# 4                                     16.0                 4.37
# ...                                    ...                  ...
# 175857                                 2.0                 4.40
# 175858                                 0.0                 0.00
# 175859                                 2.0                 4.05
# 175860                                 0.0                 0.00
# 175861                                 0.0                 0.00
#
#         CREDITO_SEM_GLOBAL  CREDITO_INTENTADO_GLOBAL  CREDITO_APROBADO_GLOBAL
# 0                      7.0                       7.0                      5.0  \
# 1                     10.0                      17.0                     15.0
# 2                      5.0                      40.0                     38.0
# 3                      2.0                      19.0                     17.0
# 4                     16.0                      24.0                     24.0
# ...                    ...                       ...                      ...
# 175857                 2.0                      26.0                     26.0
# 175858                 0.0                      16.0                     16.0
# 175859                 2.0                      26.0                     26.0
# 175860                 0.0                      24.0                     24.0
# 175861                 0.0                      16.0                     16.0
#
#         CREDITO_PGA_GLOBAL  PROMEDIO_GLOBAL CODIGO_ESTUDIANTE_ANON
# 0                      7.0             2.92             f0b2a489ae
# 1                     17.0             3.20             f0b2a489ae
# 2                     40.0             4.16             f0b2a489ae
# 3                     19.0             3.34             f0b2a489ae
# 4                     24.0             4.33             a032f2ee8d
# ...                    ...              ...                    ...
# 175857                26.0             4.59             7098f723f8
# 175858                16.0             3.64             02bcef353e
# 175859                26.0             4.35             632c31dc77
# 175860                24.0             4.73             af11302c2c
# 175861                16.0             4.28             b7b4e193f6
#
# [175862 rows x 13 columns]

# %%
ha = ha[ha["PERIODO"].astype(int) >= 201500]
ha
# Out:
#        PERIODO CODIGO_NIVEL_PROGRAMA DESCRIPCION_NIVEL_PROGRAMA  SSC
# 73296   201510                    MA                   MAGISTER  0.0  \
# 73297   201510                    MA                   MAGISTER  0.0
# 73298   201510                    MA                   MAGISTER  0.0
# 73299   201510                    MA                   MAGISTER  0.0
# 73300   201510                    MA                   MAGISTER  0.0
# ...        ...                   ...                        ...  ...
# 175857  202419                    MA                   MAGISTER  0.0
# 175858  202419                    MA                   MAGISTER  0.0
# 175859  202419                    MA                   MAGISTER  0.0
# 175860  202419                    MA                   MAGISTER  0.0
# 175861  202419                    MA                   MAGISTER  0.0
#
#         CREDITO_SEM_INTENTADO_INSTITUCIONAL
# 73296                                  10.0  \
# 73297                                   8.0
# 73298                                   8.0
# 73299                                   3.0
# 73300                                  14.0
# ...                                     ...
# 175857                                  2.0
# 175858                                  0.0
# 175859                                  2.0
# 175860                                  0.0
# 175861                                  0.0
#
#         CREDITO_SEM_APROBADO_INSTITUCIONAL  PROMEDIO_SEM_GLOBAL
# 73296                                 10.0                 4.69  \
# 73297                                  8.0                 4.32
# 73298                                  8.0                 4.73
# 73299                                  3.0                 5.00
# 73300                                 14.0                 4.43
# ...                                    ...                  ...
# 175857                                 2.0                 4.40
# 175858                                 0.0                 0.00
# 175859                                 2.0                 4.05
# 175860                                 0.0                 0.00
# 175861                                 0.0                 0.00
#
#         CREDITO_SEM_GLOBAL  CREDITO_INTENTADO_GLOBAL  CREDITO_APROBADO_GLOBAL
# 73296                 10.0                      36.0                     36.0  \
# 73297                  8.0                      24.0                     24.0
# 73298                  8.0                      24.0                     24.0
# 73299                  3.0                      65.0                     59.0
# 73300                 14.0                      28.0                     28.0
# ...                    ...                       ...                      ...
# 175857                 2.0                      26.0                     26.0
# 175858                 0.0                      16.0                     16.0
# 175859                 2.0                      26.0                     26.0
# 175860                 0.0                      24.0                     24.0
# 175861                 0.0                      16.0                     16.0
#
#         CREDITO_PGA_GLOBAL  PROMEDIO_GLOBAL CODIGO_ESTUDIANTE_ANON
# 73296                 30.0             4.64             b4a208bb58
# 73297                 24.0             4.12             bd09176db4
# 73298                 16.0             4.47             72b9dd17ac
# 73299                 54.0             4.16             aae981776b
# 73300                 23.0             4.48             ad0004a564
# ...                    ...              ...                    ...
# 175857                26.0             4.59             7098f723f8
# 175858                16.0             3.64             02bcef353e
# 175859                26.0             4.35             632c31dc77
# 175860                24.0             4.73             af11302c2c
# 175861                16.0             4.28             b7b4e193f6
#
# [86476 rows x 13 columns]

# %%
ha = ha[["PERIODO", "CODIGO_ESTUDIANTE_ANON", "CREDITO_SEM_INTENTADO_INSTITUCIONAL", "CREDITO_SEM_APROBADO_INSTITUCIONAL", "PROMEDIO_SEM_GLOBAL", "CREDITO_INTENTADO_GLOBAL", "CREDITO_APROBADO_GLOBAL", "PROMEDIO_GLOBAL"]]
ha
# Out:
#        PERIODO CODIGO_ESTUDIANTE_ANON  CREDITO_SEM_INTENTADO_INSTITUCIONAL
# 73296   201510             b4a208bb58                                 10.0  \
# 73297   201510             bd09176db4                                  8.0
# 73298   201510             72b9dd17ac                                  8.0
# 73299   201510             aae981776b                                  3.0
# 73300   201510             ad0004a564                                 14.0
# ...        ...                    ...                                  ...
# 175857  202419             7098f723f8                                  2.0
# 175858  202419             02bcef353e                                  0.0
# 175859  202419             632c31dc77                                  2.0
# 175860  202419             af11302c2c                                  0.0
# 175861  202419             b7b4e193f6                                  0.0
#
#         CREDITO_SEM_APROBADO_INSTITUCIONAL  PROMEDIO_SEM_GLOBAL
# 73296                                 10.0                 4.69  \
# 73297                                  8.0                 4.32
# 73298                                  8.0                 4.73
# 73299                                  3.0                 5.00
# 73300                                 14.0                 4.43
# ...                                    ...                  ...
# 175857                                 2.0                 4.40
# 175858                                 0.0                 0.00
# 175859                                 2.0                 4.05
# 175860                                 0.0                 0.00
# 175861                                 0.0                 0.00
#
#         CREDITO_INTENTADO_GLOBAL  CREDITO_APROBADO_GLOBAL  PROMEDIO_GLOBAL
# 73296                       36.0                     36.0             4.64
# 73297                       24.0                     24.0             4.12
# 73298                       24.0                     24.0             4.47
# 73299                       65.0                     59.0             4.16
# 73300                       28.0                     28.0             4.48
# ...                          ...                      ...              ...
# 175857                      26.0                     26.0             4.59
# 175858                      16.0                     16.0             3.64
# 175859                      26.0                     26.0             4.35
# 175860                      24.0                     24.0             4.73
# 175861                      16.0                     16.0             4.28
#
# [86476 rows x 8 columns]

# %%
ha[ha.duplicated(["CODIGO_ESTUDIANTE_ANON", "PERIODO"])]
# Out:
# Empty DataFrame
# Columns: [PERIODO, CODIGO_ESTUDIANTE_ANON, CREDITO_SEM_INTENTADO_INSTITUCIONAL, CREDITO_SEM_APROBADO_INSTITUCIONAL, PROMEDIO_SEM_GLOBAL, CREDITO_INTENTADO_GLOBAL, CREDITO_APROBADO_GLOBAL, PROMEDIO_GLOBAL]
# Index: []

# %%
info_matriculados = info_matriculados.merge(ha, on = ["CODIGO_ESTUDIANTE_ANON", "PERIODO"], how = "left")
info_matriculados
# Out:
#       PERIODO CODIGO_ESTUDIANTE_ANON  EDAD TIPO_ESTADO_CIVIL NIVEL_PROGRAMA_1
# 0      201720             db195bc7d5  46.0           SOLTERO         MAGISTER  \
# 1      201720             d708c0c540  44.0           SOLTERO         MAGISTER
# 2      201720             234b8b064c  39.0            CASADO         MAGISTER
# 3      202210             11c8bf67b0  29.0              None         MAGISTER
# 4      201720             16b83d214d  49.0        DIVORCIADO         MAGISTER
# ...       ...                    ...   ...               ...              ...
# 90347  201520             154b663b98  32.0           SOLTERO         MAGISTER
# 90348  201520             fa0a124747  40.0           SOLTERO         MAGISTER
# 90349  201520             04b110047a  36.0           SOLTERO         MAGISTER
# 90350  202411             a9f3aa1dc0  30.0           SOLTERO         MAGISTER
# 90351  202420             cb36fecc01  42.0       UNION LIBRE         MAGISTER
#
#       FACULTAD_PROGRAMA_1         DEPARTAMENTO_PROGRAMA_1
# 0                   CIDER  CENTRO INTERD.ESTUDIOS DESARR.  \
# 1       CIENCIAS SOCIALES                CIENCIA POLITICA
# 2          ADMINISTRACIÓN                  ADMINISTRACION
# 3              INGENIERÍA           INGENIERIA INDUSTRIAL
# 4               EDUCACIÓN  CENTRO INVESTIG.FORMAC.EDUCAC.
# ...                   ...                             ...
# 90347   CIENCIAS SOCIALES                CIENCIA POLITICA
# 90348      ADMINISTRACIÓN                  ADMINISTRACION
# 90349      ADMINISTRACIÓN                  ADMINISTRACION
# 90350          INGENIERÍA  INGENIERIA DE SISTEMAS Y COMPU
# 90351            MEDICINA                        MEDICINA
#
#                            PROGRAMA_1      DESC_ESTADO_ACADEMICO
# 0      MAESTRIA EN ESTUD.INTER.DESARR                     NORMAL  \
# 1        MAESTRIA EN CIENCIA POLITICA                  REINTEGRO
# 2      MAESTRIA ADMINISTRACION-MBA-TC                     NORMAL
# 3          MAESTRIA EN ING.INDUSTRIAL                     NORMAL
# 4               MAESTRIA EN EDUCACION                     NORMAL
# ...                               ...                        ...
# 90347    MAESTRIA EN CIENCIA POLITICA  PRIMER SEMESTRE POSTGRADO
# 90348            MAESTRIA EN FINANZAS  PRIMER SEMESTRE POSTGRADO
# 90349            MAESTRIA EN FINANZAS  PRIMER SEMESTRE POSTGRADO
# 90350   MAESTR.INGENIERIA DE SOFTWARE                     NORMAL
# 90351       MAESTRIA EN EPIDEMIOLOGIA  PRIMER SEMESTRE POSTGRADO
#
#        CREDITO_SEM_INTENTADO_INSTITUCIONAL
# 0                                      4.0  \
# 1                                      4.0
# 2                                      6.0
# 3                                      8.0
# 4                                      NaN
# ...                                    ...
# 90347                                 12.0
# 90348                                 12.0
# 90349                                 12.0
# 90350                                  4.0
# 90351                                  NaN
#
#        CREDITO_SEM_APROBADO_INSTITUCIONAL  PROMEDIO_SEM_GLOBAL
# 0                                     4.0                 0.00  \
# 1                                     0.0                 0.00
# 2                                     6.0                 4.04
# 3                                     8.0                 4.00
# 4                                     NaN                  NaN
# ...                                   ...                  ...
# 90347                                12.0                 4.16
# 90348                                12.0                 3.75
# 90349                                12.0                 4.54
# 90350                                 4.0                 4.60
# 90351                                 NaN                  NaN
#
#        CREDITO_INTENTADO_GLOBAL  CREDITO_APROBADO_GLOBAL  PROMEDIO_GLOBAL
# 0                          45.0                     29.0             4.23
# 1                          36.0                     32.0             4.12
# 2                          53.0                     53.0             3.88
# 3                          40.0                     40.0             4.06
# 4                           NaN                      NaN              NaN
# ...                         ...                      ...              ...
# 90347                      12.0                     12.0             4.16
# 90348                      12.0                     12.0             3.75
# 90349                      12.0                     12.0             4.54
# 90350                      36.0                     36.0             4.77
# 90351                       NaN                      NaN              NaN
#
# [90352 rows x 15 columns]

# %%
matriculas_pago = pd.read_parquet("MATRICULAS_PAGO_BASE_BECAS_MAESTRIA_Anon.parquet")
matriculas_pago
# Out:
#         PERIODO                TIPO_SECCION   CLASIFICACION_BECAS
# 0        201510  BECAS Y PRESTAMOS EXTERNOS        BECAS EXTERNAS  \
# 1        201510              BECAS INTERNAS        BECAS INTERNAS
# 2        201510               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 3        201510               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 4        201510  BECAS Y PRESTAMOS EXTERNOS        BECAS EXTERNAS
# ...         ...                         ...                   ...
# 103879   202420               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 103880   202420               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 103881   202420               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 103882   202420               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 103883   202420  BECAS Y PRESTAMOS EXTERNOS        BECAS EXTERNAS
#
#                          TIPO_BECA  PORCENTAJE_APORTE_ITEM  TOTAL_PAGADO
# 0       BECAS Y PRESTAMOS EXTERNOS                     1.0   -18850000.0  \
# 1                  BECA FACULTADES                     0.5    -4450000.0
# 2             OTRAS FORMAS DE PAGO                     0.5    -4450000.0
# 3             OTRAS FORMAS DE PAGO                     1.0    -3404000.0
# 4       BECAS Y PRESTAMOS EXTERNOS                     0.5    -4265500.0
# ...                            ...                     ...           ...
# 103879        OTRAS FORMAS DE PAGO                     1.0   -15600000.0
# 103880        OTRAS FORMAS DE PAGO                     1.0   -16850000.0
# 103881        OTRAS FORMAS DE PAGO                     1.0   -16850000.0
# 103882        OTRAS FORMAS DE PAGO                     1.0   -20220000.0
# 103883  BECAS Y PRESTAMOS EXTERNOS                     1.0   -23400000.0
#
#        ranking CODIGO_ESTUDIANTE_ANON
# 0            1             922ce7e25b
# 1            1             6c86ec510c
# 2            2             6c86ec510c
# 3            1             c132ee9e94
# 4            1             b4a208bb58
# ...        ...                    ...
# 103879       1             6e89e2d6a6
# 103880       1             3d59272626
# 103881       1             8d5a991980
# 103882       1             757aa3cbb7
# 103883       1             4e6df8d167
#
# [103884 rows x 8 columns]

# %%
# Se toma la forma de financiación que más aporta en el semestre
matriculas_pago = matriculas_pago[matriculas_pago["ranking"]=="1"]
matriculas_pago
# Out:
#         PERIODO                TIPO_SECCION   CLASIFICACION_BECAS
# 0        201510  BECAS Y PRESTAMOS EXTERNOS        BECAS EXTERNAS  \
# 1        201510              BECAS INTERNAS        BECAS INTERNAS
# 3        201510               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 4        201510  BECAS Y PRESTAMOS EXTERNOS        BECAS EXTERNAS
# 6        201510  BECAS Y PRESTAMOS EXTERNOS        BECAS EXTERNAS
# ...         ...                         ...                   ...
# 103879   202420               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 103880   202420               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 103881   202420               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 103882   202420               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 103883   202420  BECAS Y PRESTAMOS EXTERNOS        BECAS EXTERNAS
#
#                          TIPO_BECA  PORCENTAJE_APORTE_ITEM  TOTAL_PAGADO
# 0       BECAS Y PRESTAMOS EXTERNOS                     1.0   -18850000.0  \
# 1                  BECA FACULTADES                     0.5    -4450000.0
# 3             OTRAS FORMAS DE PAGO                     1.0    -3404000.0
# 4       BECAS Y PRESTAMOS EXTERNOS                     0.5    -4265500.0
# 6       BECAS Y PRESTAMOS EXTERNOS                     1.0   -23200000.0
# ...                            ...                     ...           ...
# 103879        OTRAS FORMAS DE PAGO                     1.0   -15600000.0
# 103880        OTRAS FORMAS DE PAGO                     1.0   -16850000.0
# 103881        OTRAS FORMAS DE PAGO                     1.0   -16850000.0
# 103882        OTRAS FORMAS DE PAGO                     1.0   -20220000.0
# 103883  BECAS Y PRESTAMOS EXTERNOS                     1.0   -23400000.0
#
#        ranking CODIGO_ESTUDIANTE_ANON
# 0            1             922ce7e25b
# 1            1             6c86ec510c
# 3            1             c132ee9e94
# 4            1             b4a208bb58
# 6            1             81f6ae8e33
# ...        ...                    ...
# 103879       1             6e89e2d6a6
# 103880       1             3d59272626
# 103881       1             8d5a991980
# 103882       1             757aa3cbb7
# 103883       1             4e6df8d167
#
# [86012 rows x 8 columns]

# %%
matriculas_pago = matriculas_pago[["PERIODO", "CODIGO_ESTUDIANTE_ANON", "TIPO_SECCION", "CLASIFICACION_BECAS", "TIPO_BECA"]]
matriculas_pago
# Out:
#         PERIODO CODIGO_ESTUDIANTE_ANON                TIPO_SECCION
# 0        201510             922ce7e25b  BECAS Y PRESTAMOS EXTERNOS  \
# 1        201510             6c86ec510c              BECAS INTERNAS
# 3        201510             c132ee9e94               CAJA Y BANCOS
# 4        201510             b4a208bb58  BECAS Y PRESTAMOS EXTERNOS
# 6        201510             81f6ae8e33  BECAS Y PRESTAMOS EXTERNOS
# ...         ...                    ...                         ...
# 103879   202420             6e89e2d6a6               CAJA Y BANCOS
# 103880   202420             3d59272626               CAJA Y BANCOS
# 103881   202420             8d5a991980               CAJA Y BANCOS
# 103882   202420             757aa3cbb7               CAJA Y BANCOS
# 103883   202420             4e6df8d167  BECAS Y PRESTAMOS EXTERNOS
#
#          CLASIFICACION_BECAS                   TIPO_BECA
# 0             BECAS EXTERNAS  BECAS Y PRESTAMOS EXTERNOS
# 1             BECAS INTERNAS             BECA FACULTADES
# 3       OTRAS FORMAS DE PAGO        OTRAS FORMAS DE PAGO
# 4             BECAS EXTERNAS  BECAS Y PRESTAMOS EXTERNOS
# 6             BECAS EXTERNAS  BECAS Y PRESTAMOS EXTERNOS
# ...                      ...                         ...
# 103879  OTRAS FORMAS DE PAGO        OTRAS FORMAS DE PAGO
# 103880  OTRAS FORMAS DE PAGO        OTRAS FORMAS DE PAGO
# 103881  OTRAS FORMAS DE PAGO        OTRAS FORMAS DE PAGO
# 103882  OTRAS FORMAS DE PAGO        OTRAS FORMAS DE PAGO
# 103883        BECAS EXTERNAS  BECAS Y PRESTAMOS EXTERNOS
#
# [86012 rows x 5 columns]

# %%
matriculas_pago[matriculas_pago.duplicated(subset = ["CODIGO_ESTUDIANTE_ANON", "PERIODO"])]
# Out:
# Empty DataFrame
# Columns: [PERIODO, CODIGO_ESTUDIANTE_ANON, TIPO_SECCION, CLASIFICACION_BECAS, TIPO_BECA]
# Index: []

# %%
matriculas_pago["PERIODO"]=matriculas_pago["PERIODO"].astype(str)
# Out:
# /var/folders/r5/cc3y743j5ys_g9v6b67d72jh0000gn/T/ipykernel_59586/3581404382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matriculas_pago["PERIODO"]=matriculas_pago["PERIODO"].astype(str)

# %%
info_matriculados = info_matriculados.merge(matriculas_pago, on = ["CODIGO_ESTUDIANTE_ANON", "PERIODO"], how = "left")
info_matriculados
# Out:
#       PERIODO CODIGO_ESTUDIANTE_ANON  EDAD TIPO_ESTADO_CIVIL NIVEL_PROGRAMA_1
# 0      201720             db195bc7d5  46.0           SOLTERO         MAGISTER  \
# 1      201720             d708c0c540  44.0           SOLTERO         MAGISTER
# 2      201720             234b8b064c  39.0            CASADO         MAGISTER
# 3      202210             11c8bf67b0  29.0              None         MAGISTER
# 4      201720             16b83d214d  49.0        DIVORCIADO         MAGISTER
# ...       ...                    ...   ...               ...              ...
# 90347  201520             154b663b98  32.0           SOLTERO         MAGISTER
# 90348  201520             fa0a124747  40.0           SOLTERO         MAGISTER
# 90349  201520             04b110047a  36.0           SOLTERO         MAGISTER
# 90350  202411             a9f3aa1dc0  30.0           SOLTERO         MAGISTER
# 90351  202420             cb36fecc01  42.0       UNION LIBRE         MAGISTER
#
#       FACULTAD_PROGRAMA_1         DEPARTAMENTO_PROGRAMA_1
# 0                   CIDER  CENTRO INTERD.ESTUDIOS DESARR.  \
# 1       CIENCIAS SOCIALES                CIENCIA POLITICA
# 2          ADMINISTRACIÓN                  ADMINISTRACION
# 3              INGENIERÍA           INGENIERIA INDUSTRIAL
# 4               EDUCACIÓN  CENTRO INVESTIG.FORMAC.EDUCAC.
# ...                   ...                             ...
# 90347   CIENCIAS SOCIALES                CIENCIA POLITICA
# 90348      ADMINISTRACIÓN                  ADMINISTRACION
# 90349      ADMINISTRACIÓN                  ADMINISTRACION
# 90350          INGENIERÍA  INGENIERIA DE SISTEMAS Y COMPU
# 90351            MEDICINA                        MEDICINA
#
#                            PROGRAMA_1      DESC_ESTADO_ACADEMICO
# 0      MAESTRIA EN ESTUD.INTER.DESARR                     NORMAL  \
# 1        MAESTRIA EN CIENCIA POLITICA                  REINTEGRO
# 2      MAESTRIA ADMINISTRACION-MBA-TC                     NORMAL
# 3          MAESTRIA EN ING.INDUSTRIAL                     NORMAL
# 4               MAESTRIA EN EDUCACION                     NORMAL
# ...                               ...                        ...
# 90347    MAESTRIA EN CIENCIA POLITICA  PRIMER SEMESTRE POSTGRADO
# 90348            MAESTRIA EN FINANZAS  PRIMER SEMESTRE POSTGRADO
# 90349            MAESTRIA EN FINANZAS  PRIMER SEMESTRE POSTGRADO
# 90350   MAESTR.INGENIERIA DE SOFTWARE                     NORMAL
# 90351       MAESTRIA EN EPIDEMIOLOGIA  PRIMER SEMESTRE POSTGRADO
#
#        CREDITO_SEM_INTENTADO_INSTITUCIONAL
# 0                                      4.0  \
# 1                                      4.0
# 2                                      6.0
# 3                                      8.0
# 4                                      NaN
# ...                                    ...
# 90347                                 12.0
# 90348                                 12.0
# 90349                                 12.0
# 90350                                  4.0
# 90351                                  NaN
#
#        CREDITO_SEM_APROBADO_INSTITUCIONAL  PROMEDIO_SEM_GLOBAL
# 0                                     4.0                 0.00  \
# 1                                     0.0                 0.00
# 2                                     6.0                 4.04
# 3                                     8.0                 4.00
# 4                                     NaN                  NaN
# ...                                   ...                  ...
# 90347                                12.0                 4.16
# 90348                                12.0                 3.75
# 90349                                12.0                 4.54
# 90350                                 4.0                 4.60
# 90351                                 NaN                  NaN
#
#        CREDITO_INTENTADO_GLOBAL  CREDITO_APROBADO_GLOBAL  PROMEDIO_GLOBAL
# 0                          45.0                     29.0             4.23  \
# 1                          36.0                     32.0             4.12
# 2                          53.0                     53.0             3.88
# 3                          40.0                     40.0             4.06
# 4                           NaN                      NaN              NaN
# ...                         ...                      ...              ...
# 90347                      12.0                     12.0             4.16
# 90348                      12.0                     12.0             3.75
# 90349                      12.0                     12.0             4.54
# 90350                      36.0                     36.0             4.77
# 90351                       NaN                      NaN              NaN
#
#                      TIPO_SECCION   CLASIFICACION_BECAS
# 0                   CAJA Y BANCOS  OTRAS FORMAS DE PAGO  \
# 1                   CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 2         PRESTAMOS REEMBOLSABLES  OTRAS FORMAS DE PAGO
# 3                  BECAS INTERNAS        BECAS INTERNAS
# 4                             NaN                   NaN
# ...                           ...                   ...
# 90347  BECAS Y PRESTAMOS EXTERNOS        BECAS EXTERNAS
# 90348               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 90349               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 90350               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 90351               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
#
#                         TIPO_BECA
# 0            OTRAS FORMAS DE PAGO
# 1            OTRAS FORMAS DE PAGO
# 2            OTRAS FORMAS DE PAGO
# 3              BECA MAESTRIA BEPS
# 4                             NaN
# ...                           ...
# 90347  BECAS Y PRESTAMOS EXTERNOS
# 90348        OTRAS FORMAS DE PAGO
# 90349        OTRAS FORMAS DE PAGO
# 90350        OTRAS FORMAS DE PAGO
# 90351        OTRAS FORMAS DE PAGO
#
# [90352 rows x 18 columns]

# %%
info_admitidos = pd.read_parquet("Info_Admitidos_General_Anon.parquet")
info_admitidos
# Out:
#       PERIODO  NUMERO_APLICACION DESCRIPCION_DECISION_ADMISION
# 0      197220                1.0    DECISION TOMADA (ADMITIDO)  \
# 1      197510                1.0        COMPLETA PARA REVISION
# 2      198020                1.0    DECISION TOMADA (ADMITIDO)
# 3      198020                1.0    DECISION TOMADA (ADMITIDO)
# 4      198020                1.0    DECISION TOMADA (ADMITIDO)
# ...       ...                ...                           ...
# 71353  202510                5.0     INCOMPLETA POR REQUISITOS
# 71354  202510                5.0                   NO ADMITIDO
# 71355  202510                5.0                   NO ADMITIDO
# 71356  202510                6.0                   NO ADMITIDO
# 71357  202510                9.0                   NO ADMITIDO
#
#       DESCRIPCION_TIPO_ADMISION DESCRIPCION_TIPO_ESTUDIANTE CODIGO_PROGRAMA
# 0                     POSTGRADO                   POSTGRADO          M-ECON  \
# 1                     POSTGRADO                   POSTGRADO          M-ICIV
# 2                 PUNTAJE ICFES             NORMAL PREGRADO          M-ADMI
# 3                 PUNTAJE ICFES             NORMAL PREGRADO          M-ADMI
# 4                 PUNTAJE ICFES             NORMAL PREGRADO          M-ADMI
# ...                         ...                         ...             ...
# 71353                 POSTGRADO                   POSTGRADO          M-EMBA
# 71354                 POSTGRADO                   POSTGRADO          M-EMBA
# 71355                 POSTGRADO                   POSTGRADO          M-EMBA
# 71356                 POSTGRADO                   POSTGRADO          M-EMBA
# 71357                 POSTGRADO                   POSTGRADO          M-EMBA
#
#               DESCRIPCION_PROGRAMA CODIGO_NIVEL_PROGRAMA
# 0             MAESTRIA EN ECONOMIA                    MA  \
# 1            MAESTRIA EN ING.CIVIL                    MA
# 2       MAESTRIA EN ADMINISTRACION                    MA
# 3       MAESTRIA EN ADMINISTRACION                    MA
# 4       MAESTRIA EN ADMINISTRACION                    MA
# ...                            ...                   ...
# 71353  MAESTRIA EN ADMON EJECUTIVO                    MA
# 71354  MAESTRIA EN ADMON EJECUTIVO                    MA
# 71355  MAESTRIA EN ADMON EJECUTIVO                    MA
# 71356  MAESTRIA EN ADMON EJECUTIVO                    MA
# 71357  MAESTRIA EN ADMON EJECUTIVO                    MA
#
#       DESCRIPCION_NIVEL_PROGRAMA CODIGO_FACULTAD_PROGRAMA
# 0                       MAGISTER                       EC  \
# 1                       MAGISTER                       IN
# 2                       MAGISTER                       AD
# 3                       MAGISTER                       AD
# 4                       MAGISTER                       AD
# ...                          ...                      ...
# 71353                   MAGISTER                       AD
# 71354                   MAGISTER                       AD
# 71355                   MAGISTER                       AD
# 71356                   MAGISTER                       AD
# 71357                   MAGISTER                       AD
#
#       DESCRIPCION_FACULTAD_PROGRAMA CODIGO_DEPARTAMENTO_PROGRAMA
# 0                          ECONOMÍA                         ECON  \
# 1                        INGENIERÍA                         ICIV
# 2                    ADMINISTRACIÓN                         None
# 3                    ADMINISTRACIÓN                         None
# 4                    ADMINISTRACIÓN                         None
# ...                             ...                          ...
# 71353                ADMINISTRACIÓN                         ADMI
# 71354                ADMINISTRACIÓN                         ADMI
# 71355                ADMINISTRACIÓN                         ADMI
# 71356                ADMINISTRACIÓN                         ADMI
# 71357                ADMINISTRACIÓN                         ADMI
#
#       DESCRIPCION_DEPARTAMENTO_PROGRAMA     CIUDAD_NACIMIENTO NACIONALIDAD
# 0                              ECONOMIA                  None         None  \
# 1                      INGENIERIA CIVIL                  None         None
# 2                                  None               ARMENIA         None
# 3                                  None  SANTAFE DE BOGOTA D.         None
# 4                                  None  SANTAFE DE BOGOTA D.         None
# ...                                 ...                   ...          ...
# 71353                    ADMINISTRACION           BOGOTA D.C.           CO
# 71354                    ADMINISTRACION         VILLAVICENCIO           CO
# 71355                    ADMINISTRACION           BOGOTA D.C.           CO
# 71356                    ADMINISTRACION           BOGOTA D.C.           CO
# 71357                    ADMINISTRACION               PEREIRA           CO
#
#       DESCRIPCION_NACIONALIDAD  EDAD DESCRIPCION_SEXO ESTADO_CIVIL
# 0                         None  24.0        MASCULINO            C  \
# 1                         None  18.0        MASCULINO            C
# 2                         None  28.0        MASCULINO            C
# 3                         None  30.0        MASCULINO            S
# 4                         None  25.0        MASCULINO            S
# ...                        ...   ...              ...          ...
# 71353               COLOMBIANO  25.0         FEMENINO            S
# 71354               COLOMBIANO  34.0        MASCULINO            C
# 71355               COLOMBIANO  32.0        MASCULINO            S
# 71356               COLOMBIANO  37.0        MASCULINO            C
# 71357               COLOMBIANO   1.0        MASCULINO            S
#
#             CIUDAD CODIGO_DEPARTAMENTO CODIGO_PAIS ESTRATO TIPO_VIVIENDA
# 0            FLORA                  00          00    None          None  \
# 1            TUNJA                  15          34    None          None
# 2      BOGOTA D.C.                  11          34    None          None
# 3      BOGOTA D.C.                  11          34    None          None
# 4        SÃO PAULO                 429          20    None          None
# ...            ...                 ...         ...     ...           ...
# 71353  BOGOTA D.C.                  11          34    None          None
# 71354  BOGOTA D.C.                  11          34    None          None
# 71355  BOGOTA D.C.                  11          34    None          None
# 71356  BOGOTA D.C.                  11          34    None          None
# 71357  BOGOTA D.C.                  11          34    None          None
#
#       PERTENECE_MINORIA_ETNICA SISBEN PUN_SISBEN
# 0                         None   None       None  \
# 1                         None   None       None
# 2                         None   None       None
# 3                         None   None       None
# 4                         None   None       None
# ...                        ...    ...        ...
# 71353                     None   None       None
# 71354                     None   None       None
# 71355                     None   None       None
# 71356                     None   None       None
# 71357                     None   None       None
#
#       NOMBRE_SECTOR_EMPRESA_ESTUDIANTE CARGO_ESTUDIANTE       TITULO_OBTENIDO
# 0                                 None             None                  None  \
# 1                                 None             None                  None
# 2                                 None             None                  None
# 3                                 None             None                  None
# 4                                 None             None                  None
# ...                                ...              ...                   ...
# 71353                          PRIVADO             None         ADMINISTRADOR
# 71354                          PRIVADO          GERENTE  INGENIERO INDUSTRIAL
# 71355                          PRIVADO          GERENTE                  None
# 71356                          PRIVADO             JEFE             DISEÑADOR
# 71357                          PRIVADO             None               ABOGADO
#
#       PROMEDIO_ACUMULADO FECHA_GRADO_PS
# 0                   None            NaT  \
# 1                   None            NaT
# 2                   None            NaT
# 3                   None            NaT
# 4                   None            NaT
# ...                  ...            ...
# 71353               4.10     2023-10-17
# 71354               4.04     2014-08-26
# 71355               3.90     2016-06-03
# 71356               None            NaT
# 71357               4.10     2024-04-05
#
#                                    FORMA_DE_FINANCIACION
# 0                                                   None  \
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 71353                              BECA RECURSOS_PROPIOS
# 71354                     APOYO_EMPRESA RECURSOS_PROPIOS
# 71355                FINANCIACION_BANCO RECURSOS_PROPIOS
# 71356   APOYO_EMPRESA FINANCIACION_BANCO RECURSOS_PRO...
# 71357                                 APOYO_EMPRESA BECA
#
#       REQUIERE_APOYO_FINANCIERO PORCENTAJE_TIEMPO_PARA_ESTUDIO
# 0                             N                           None  \
# 1                             N                           None
# 2                             N                           None
# 3                             N                           None
# 4                             N                           None
# ...                         ...                            ...
# 71353                         Y                            100
# 71354                         N                             25
# 71355                         Y                             20
# 71356                         Y                             30
# 71357                         Y                             90
#
#       CIUDAD_RESIDENCIA_UG DEPARTAMENTO_RESIDENCIA_UG PAIS_RESIDENCIA_UG
# 0                     None                       None               None  \
# 1                    TUNJA                     BOYACÁ           COLOMBIA
# 2             BOGOTÁ, D.C.               BOGOTÁ, D.C.           COLOMBIA
# 3             BOGOTÁ, D.C.               BOGOTÁ, D.C.           COLOMBIA
# 4          POÇOS DE CALDAS               MINAS GERAIS             BRASIL
# ...                    ...                        ...                ...
# 71353         BOGOTÁ, D.C.               BOGOTÁ, D.C.           COLOMBIA
# 71354         BOGOTÁ, D.C.               BOGOTÁ, D.C.           COLOMBIA
# 71355         BOGOTÁ, D.C.               BOGOTÁ, D.C.           COLOMBIA
# 71356         BOGOTÁ, D.C.               BOGOTÁ, D.C.           COLOMBIA
# 71357         BOGOTÁ, D.C.               BOGOTÁ, D.C.           COLOMBIA
#
#       CODIGO_ESTUDIANTE_ANON
# 0                 aeece5705c
# 1                 9f3a56fd77
# 2                 16627d24c7
# 3                 1b363ca340
# 4                 645cdca909
# ...                      ...
# 71353             2fb2fe9523
# 71354             e0149a984c
# 71355             2a5443c238
# 71356             c6fa927c82
# 71357             3570ff266d
#
# [71358 rows x 39 columns]

# %%
info_admitidos = info_admitidos[["CODIGO_ESTUDIANTE_ANON", "DESCRIPCION_SEXO", "ESTRATO", "TIPO_VIVIENDA", "PERTENECE_MINORIA_ETNICA", "SISBEN", "PUN_SISBEN", "NOMBRE_SECTOR_EMPRESA_ESTUDIANTE", "CARGO_ESTUDIANTE", "FECHA_GRADO_PS", "PORCENTAJE_TIEMPO_PARA_ESTUDIO", "CIUDAD_RESIDENCIA_UG", "DEPARTAMENTO_RESIDENCIA_UG", "PAIS_RESIDENCIA_UG"]]
info_admitidos
# Out:
#       CODIGO_ESTUDIANTE_ANON DESCRIPCION_SEXO ESTRATO TIPO_VIVIENDA
# 0                 aeece5705c        MASCULINO    None          None  \
# 1                 9f3a56fd77        MASCULINO    None          None
# 2                 16627d24c7        MASCULINO    None          None
# 3                 1b363ca340        MASCULINO    None          None
# 4                 645cdca909        MASCULINO    None          None
# ...                      ...              ...     ...           ...
# 71353             2fb2fe9523         FEMENINO    None          None
# 71354             e0149a984c        MASCULINO    None          None
# 71355             2a5443c238        MASCULINO    None          None
# 71356             c6fa927c82        MASCULINO    None          None
# 71357             3570ff266d        MASCULINO    None          None
#
#       PERTENECE_MINORIA_ETNICA SISBEN PUN_SISBEN
# 0                         None   None       None  \
# 1                         None   None       None
# 2                         None   None       None
# 3                         None   None       None
# 4                         None   None       None
# ...                        ...    ...        ...
# 71353                     None   None       None
# 71354                     None   None       None
# 71355                     None   None       None
# 71356                     None   None       None
# 71357                     None   None       None
#
#       NOMBRE_SECTOR_EMPRESA_ESTUDIANTE CARGO_ESTUDIANTE FECHA_GRADO_PS
# 0                                 None             None            NaT  \
# 1                                 None             None            NaT
# 2                                 None             None            NaT
# 3                                 None             None            NaT
# 4                                 None             None            NaT
# ...                                ...              ...            ...
# 71353                          PRIVADO             None     2023-10-17
# 71354                          PRIVADO          GERENTE     2014-08-26
# 71355                          PRIVADO          GERENTE     2016-06-03
# 71356                          PRIVADO             JEFE            NaT
# 71357                          PRIVADO             None     2024-04-05
#
#       PORCENTAJE_TIEMPO_PARA_ESTUDIO CIUDAD_RESIDENCIA_UG
# 0                               None                 None  \
# 1                               None                TUNJA
# 2                               None         BOGOTÁ, D.C.
# 3                               None         BOGOTÁ, D.C.
# 4                               None      POÇOS DE CALDAS
# ...                              ...                  ...
# 71353                            100         BOGOTÁ, D.C.
# 71354                             25         BOGOTÁ, D.C.
# 71355                             20         BOGOTÁ, D.C.
# 71356                             30         BOGOTÁ, D.C.
# 71357                             90         BOGOTÁ, D.C.
#
#       DEPARTAMENTO_RESIDENCIA_UG PAIS_RESIDENCIA_UG
# 0                           None               None
# 1                         BOYACÁ           COLOMBIA
# 2                   BOGOTÁ, D.C.           COLOMBIA
# 3                   BOGOTÁ, D.C.           COLOMBIA
# 4                   MINAS GERAIS             BRASIL
# ...                          ...                ...
# 71353               BOGOTÁ, D.C.           COLOMBIA
# 71354               BOGOTÁ, D.C.           COLOMBIA
# 71355               BOGOTÁ, D.C.           COLOMBIA
# 71356               BOGOTÁ, D.C.           COLOMBIA
# 71357               BOGOTÁ, D.C.           COLOMBIA
#
# [71358 rows x 14 columns]

# %%
# Agrupar por 'CODIGO_ESTUDIANTE_ANON' y quedarse con el valor no nulo (primero no NaN)
df_combined = info_admitidos.groupby('CODIGO_ESTUDIANTE_ANON').apply(lambda group: group.ffill().bfill().iloc[0])

# Si deseas resetear el índice
df_combined = df_combined.reset_index(drop=True)

# Ver el DataFrame resultante
df_combined
# Out:
#       CODIGO_ESTUDIANTE_ANON DESCRIPCION_SEXO ESTRATO TIPO_VIVIENDA
# 0                 0000fa1884        MASCULINO    None          None  \
# 1                 0003496395         FEMENINO    None          None
# 2                 00048d9020        MASCULINO    None          None
# 3                 0005234b85        MASCULINO    None          None
# 4                 0005803e45        MASCULINO    None          None
# ...                      ...              ...     ...           ...
# 57322             fffc06124b        MASCULINO    None          None
# 57323             fffe02bd81        MASCULINO    None          None
# 57324             fffe7e7861        MASCULINO    None          None
# 57325             fffed043b9         FEMENINO    None          None
# 57326             ffff77862d         FEMENINO    None          None
#
#       PERTENECE_MINORIA_ETNICA SISBEN PUN_SISBEN
# 0                         None   None       None  \
# 1                         None   None       None
# 2                         None   None       None
# 3                         None   None       None
# 4                         None   None       None
# ...                        ...    ...        ...
# 57322                     None   None       None
# 57323                     None   None       None
# 57324                     None   None       None
# 57325                     None   None       None
# 57326                     None   None       None
#
#       NOMBRE_SECTOR_EMPRESA_ESTUDIANTE CARGO_ESTUDIANTE FECHA_GRADO_PS
# 0                                 None             None            NaT  \
# 1                                MIXTO        INGENIERO     2011-12-02
# 2                                 None             None     2012-01-01
# 3                                 None             None            NaT
# 4                                 None             None     2015-01-01
# ...                                ...              ...            ...
# 57322                          PRIVADO             None            NaT
# 57323                          PUBLICO           DECANO     2010-10-30
# 57324                          PRIVADO        INGENIERO     2014-06-20
# 57325                          PUBLICO             None     2007-05-31
# 57326                             None             None     2020-05-20
#
#       PORCENTAJE_TIEMPO_PARA_ESTUDIO CIUDAD_RESIDENCIA_UG
# 0                               100%                 None  \
# 1                                 40            LA CALERA
# 2                               None         BOGOTÁ, D.C.
# 3                                1/2         BOGOTÁ, D.C.
# 4                               None         BOGOTÁ, D.C.
# ...                              ...                  ...
# 57322                            40%         BOGOTÁ, D.C.
# 57323                             40         BARRANQUILLA
# 57324                           None         BOGOTÁ, D.C.
# 57325                            60%         BOGOTÁ, D.C.
# 57326                             80         BOGOTÁ, D.C.
#
#       DEPARTAMENTO_RESIDENCIA_UG PAIS_RESIDENCIA_UG
# 0                           None               None
# 1                   CUNDINAMARCA           COLOMBIA
# 2                   BOGOTÁ, D.C.           COLOMBIA
# 3                   BOGOTÁ, D.C.           COLOMBIA
# 4                   BOGOTÁ, D.C.           COLOMBIA
# ...                          ...                ...
# 57322               BOGOTÁ, D.C.           COLOMBIA
# 57323                  ATLÁNTICO           COLOMBIA
# 57324               BOGOTÁ, D.C.           COLOMBIA
# 57325               BOGOTÁ, D.C.           COLOMBIA
# 57326               BOGOTÁ, D.C.           COLOMBIA
#
# [57327 rows x 14 columns]

# %%
df_combined[df_combined.duplicated(subset = ["CODIGO_ESTUDIANTE_ANON"])]
# Out:
# Empty DataFrame
# Columns: [CODIGO_ESTUDIANTE_ANON, DESCRIPCION_SEXO, ESTRATO, TIPO_VIVIENDA, PERTENECE_MINORIA_ETNICA, SISBEN, PUN_SISBEN, NOMBRE_SECTOR_EMPRESA_ESTUDIANTE, CARGO_ESTUDIANTE, FECHA_GRADO_PS, PORCENTAJE_TIEMPO_PARA_ESTUDIO, CIUDAD_RESIDENCIA_UG, DEPARTAMENTO_RESIDENCIA_UG, PAIS_RESIDENCIA_UG]
# Index: []

# %%
info_matriculados = info_matriculados.merge(df_combined, on = ["CODIGO_ESTUDIANTE_ANON"], how = "left")
info_matriculados
# Out:
#       PERIODO CODIGO_ESTUDIANTE_ANON  EDAD TIPO_ESTADO_CIVIL NIVEL_PROGRAMA_1
# 0      201720             db195bc7d5  46.0           SOLTERO         MAGISTER  \
# 1      201720             d708c0c540  44.0           SOLTERO         MAGISTER
# 2      201720             234b8b064c  39.0            CASADO         MAGISTER
# 3      202210             11c8bf67b0  29.0              None         MAGISTER
# 4      201720             16b83d214d  49.0        DIVORCIADO         MAGISTER
# ...       ...                    ...   ...               ...              ...
# 90347  201520             154b663b98  32.0           SOLTERO         MAGISTER
# 90348  201520             fa0a124747  40.0           SOLTERO         MAGISTER
# 90349  201520             04b110047a  36.0           SOLTERO         MAGISTER
# 90350  202411             a9f3aa1dc0  30.0           SOLTERO         MAGISTER
# 90351  202420             cb36fecc01  42.0       UNION LIBRE         MAGISTER
#
#       FACULTAD_PROGRAMA_1         DEPARTAMENTO_PROGRAMA_1
# 0                   CIDER  CENTRO INTERD.ESTUDIOS DESARR.  \
# 1       CIENCIAS SOCIALES                CIENCIA POLITICA
# 2          ADMINISTRACIÓN                  ADMINISTRACION
# 3              INGENIERÍA           INGENIERIA INDUSTRIAL
# 4               EDUCACIÓN  CENTRO INVESTIG.FORMAC.EDUCAC.
# ...                   ...                             ...
# 90347   CIENCIAS SOCIALES                CIENCIA POLITICA
# 90348      ADMINISTRACIÓN                  ADMINISTRACION
# 90349      ADMINISTRACIÓN                  ADMINISTRACION
# 90350          INGENIERÍA  INGENIERIA DE SISTEMAS Y COMPU
# 90351            MEDICINA                        MEDICINA
#
#                            PROGRAMA_1      DESC_ESTADO_ACADEMICO
# 0      MAESTRIA EN ESTUD.INTER.DESARR                     NORMAL  \
# 1        MAESTRIA EN CIENCIA POLITICA                  REINTEGRO
# 2      MAESTRIA ADMINISTRACION-MBA-TC                     NORMAL
# 3          MAESTRIA EN ING.INDUSTRIAL                     NORMAL
# 4               MAESTRIA EN EDUCACION                     NORMAL
# ...                               ...                        ...
# 90347    MAESTRIA EN CIENCIA POLITICA  PRIMER SEMESTRE POSTGRADO
# 90348            MAESTRIA EN FINANZAS  PRIMER SEMESTRE POSTGRADO
# 90349            MAESTRIA EN FINANZAS  PRIMER SEMESTRE POSTGRADO
# 90350   MAESTR.INGENIERIA DE SOFTWARE                     NORMAL
# 90351       MAESTRIA EN EPIDEMIOLOGIA  PRIMER SEMESTRE POSTGRADO
#
#        CREDITO_SEM_INTENTADO_INSTITUCIONAL
# 0                                      4.0  \
# 1                                      4.0
# 2                                      6.0
# 3                                      8.0
# 4                                      NaN
# ...                                    ...
# 90347                                 12.0
# 90348                                 12.0
# 90349                                 12.0
# 90350                                  4.0
# 90351                                  NaN
#
#        CREDITO_SEM_APROBADO_INSTITUCIONAL  PROMEDIO_SEM_GLOBAL
# 0                                     4.0                 0.00  \
# 1                                     0.0                 0.00
# 2                                     6.0                 4.04
# 3                                     8.0                 4.00
# 4                                     NaN                  NaN
# ...                                   ...                  ...
# 90347                                12.0                 4.16
# 90348                                12.0                 3.75
# 90349                                12.0                 4.54
# 90350                                 4.0                 4.60
# 90351                                 NaN                  NaN
#
#        CREDITO_INTENTADO_GLOBAL  CREDITO_APROBADO_GLOBAL  PROMEDIO_GLOBAL
# 0                          45.0                     29.0             4.23  \
# 1                          36.0                     32.0             4.12
# 2                          53.0                     53.0             3.88
# 3                          40.0                     40.0             4.06
# 4                           NaN                      NaN              NaN
# ...                         ...                      ...              ...
# 90347                      12.0                     12.0             4.16
# 90348                      12.0                     12.0             3.75
# 90349                      12.0                     12.0             4.54
# 90350                      36.0                     36.0             4.77
# 90351                       NaN                      NaN              NaN
#
#                      TIPO_SECCION   CLASIFICACION_BECAS
# 0                   CAJA Y BANCOS  OTRAS FORMAS DE PAGO  \
# 1                   CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 2         PRESTAMOS REEMBOLSABLES  OTRAS FORMAS DE PAGO
# 3                  BECAS INTERNAS        BECAS INTERNAS
# 4                             NaN                   NaN
# ...                           ...                   ...
# 90347  BECAS Y PRESTAMOS EXTERNOS        BECAS EXTERNAS
# 90348               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 90349               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 90350               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
# 90351               CAJA Y BANCOS  OTRAS FORMAS DE PAGO
#
#                         TIPO_BECA DESCRIPCION_SEXO ESTRATO TIPO_VIVIENDA
# 0            OTRAS FORMAS DE PAGO        MASCULINO    None          None  \
# 1            OTRAS FORMAS DE PAGO        MASCULINO    None          None
# 2            OTRAS FORMAS DE PAGO        MASCULINO    None          None
# 3              BECA MAESTRIA BEPS        MASCULINO    None          None
# 4                             NaN         FEMENINO    None          None
# ...                           ...              ...     ...           ...
# 90347  BECAS Y PRESTAMOS EXTERNOS        MASCULINO    None          None
# 90348        OTRAS FORMAS DE PAGO        MASCULINO    None          None
# 90349        OTRAS FORMAS DE PAGO         FEMENINO    None          None
# 90350        OTRAS FORMAS DE PAGO        MASCULINO    None          None
# 90351        OTRAS FORMAS DE PAGO        MASCULINO    None          None
#
#       PERTENECE_MINORIA_ETNICA SISBEN PUN_SISBEN
# 0                         None   None       None  \
# 1                         None   None       None
# 2                         None   None       None
# 3                         None   None       None
# 4                         None   None       None
# ...                        ...    ...        ...
# 90347                     None   None       None
# 90348                     None   None       None
# 90349                     None   None       None
# 90350                     None   None       None
# 90351                     None   None       None
#
#       NOMBRE_SECTOR_EMPRESA_ESTUDIANTE CARGO_ESTUDIANTE FECHA_GRADO_PS
# 0                              PUBLICO             None     2008-02-20  \
# 1                              PRIVADO             None     2003-04-11
# 2                                 None             None     2009-01-01
# 3                                 None             None     2017-02-28
# 4                              PUBLICO         PROFESOR     2006-12-13
# ...                                ...              ...            ...
# 90347                          PUBLICO      PROFESIONAL     2014-12-04
# 90348                             None             None     2012-01-01
# 90349                             None             None     2010-01-01
# 90350                          PRIVADO        INGENIERO     2018-04-03
# 90351                          PRIVADO           MEDICO     2005-07-08
#
#       PORCENTAJE_TIEMPO_PARA_ESTUDIO CIUDAD_RESIDENCIA_UG
# 0                                 40         BOGOTÁ, D.C.  \
# 1                                  ⅓         BOGOTÁ, D.C.
# 2                               None         BOGOTÁ, D.C.
# 3                               100%         BOGOTÁ, D.C.
# 4                                30%         BOGOTÁ, D.C.
# ...                              ...                  ...
# 90347                            60%         BOGOTÁ, D.C.
# 90348                           None         BOGOTÁ, D.C.
# 90349                           None         BOGOTÁ, D.C.
# 90350                             20         BOGOTÁ, D.C.
# 90351                            50%         BOGOTÁ, D.C.
#
#       DEPARTAMENTO_RESIDENCIA_UG PAIS_RESIDENCIA_UG
# 0                   BOGOTÁ, D.C.           COLOMBIA
# 1                   BOGOTÁ, D.C.           COLOMBIA
# 2                   BOGOTÁ, D.C.           COLOMBIA
# 3                   BOGOTÁ, D.C.           COLOMBIA
# 4                   BOGOTÁ, D.C.           COLOMBIA
# ...                          ...                ...
# 90347               BOGOTÁ, D.C.           COLOMBIA
# 90348               BOGOTÁ, D.C.           COLOMBIA
# 90349               BOGOTÁ, D.C.           COLOMBIA
# 90350               BOGOTÁ, D.C.           COLOMBIA
# 90351               BOGOTÁ, D.C.           COLOMBIA
#
# [90352 rows x 31 columns]

# %%
# #!pip install ydata_profiling
# from pandas_profiling import ProfileReport
# profiling = ProfileReport(info_matriculados.copy())
# profiling.to_file("profiling.html")

# %% [markdown]
# ### Análisis Univariado

# %% [markdown]
# #### Facultad

# %%
info_matriculados['FACULTAD_PROGRAMA_1'].value_counts(dropna=False, normalize=True)
# Out:
# FACULTAD_PROGRAMA_1
# INGENIERÍA                        0.372842
# ADMINISTRACIÓN                    0.248683
# CIENCIAS SOCIALES                 0.059965
# ECONOMÍA                          0.058947
# EDUCACIÓN                         0.049695
# ESC DE GOBIERNO ALBERTO LLERAS    0.045599
# DERECHO                           0.037564
# CIDER                             0.034941
# CIENCIAS                          0.030669
# ARTES Y HUMANIDADES               0.025877
# ARQUITECTURA Y DISEÑO             0.016004
# MEDICINA                          0.008246
# DECANATURA DE ESTUDIANTES         0.005556
# CENTRO INV.Y FORM EDUC.(CIFE)     0.005412
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Group the data by 'FACULTAD_PROGRAMA_1' and count unique 'CODIGO_ESTUDIANTE_ANON'
facultad_counts = info_matriculados.groupby('FACULTAD_PROGRAMA_1')['CODIGO_ESTUDIANTE_ANON'].nunique().reset_index()

# Sort by the count of unique 'CODIGO_ESTUDIANTE_ANON'
facultad_counts = facultad_counts.sort_values(by='CODIGO_ESTUDIANTE_ANON', ascending=False)

# PLOT ROOM TYPE DISTRIBUTION BASED ON UNIQUE 'CODIGO_ESTUDIANTE_ANON'
plt.figure(figsize=(10, 6))
ax = sns.barplot(data=facultad_counts, y='FACULTAD_PROGRAMA_1', x='CODIGO_ESTUDIANTE_ANON', order=facultad_counts['FACULTAD_PROGRAMA_1'])
plt.title('Cantidad de estudiantes por facultad')
plt.xlabel('Cantidad de estudiantes')
plt.ylabel('Facultad')

# Add value labels to the bars
for p in ax.patches:
    ax.annotate(f'{p.get_width():.0f}', (p.get_width() + 1, p.get_y() + 0.5), ha='left', va='center')

plt.show()

# %% [markdown]
# **Insight**
# - La mayoría de personas que realizan una maestría en los Andes son de la facultad de Ingeniería y Administración.
# - 37.28% son de Ingeniería, mientras que el 24.87% son de Administración.

# %% [markdown]
# #### Edad

# %%
edad_entrada = info_matriculados.groupby('CODIGO_ESTUDIANTE_ANON')["EDAD"].min().reset_index()

# %%
edad_entrada.describe(percentiles=[0.05, 0.25, 0.5, 0.75, 0.95, 0.99])
# Out:
#                EDAD
# count  21190.000000
# mean      34.994384
# std       14.971851
# min        0.000000
# 5%        25.000000
# 25%       30.000000
# 50%       34.000000
# 75%       39.000000
# 95%       49.000000
# 99%       56.000000
# max     1934.000000

# %%
# Cálculos para un umbral de detección de outliers
q1 = edad_entrada["EDAD"].quantile(0.10)
q3 = edad_entrada["EDAD"].quantile(0.90)
iqr = q3 - q1
items = edad_entrada[edad_entrada["EDAD"] <= (q3 + 1.5 * iqr)]

# %%
items.describe()
# Out:
#                EDAD
# count  21183.000000
# mean      34.890809
# std        7.293406
# min        0.000000
# 25%       30.000000
# 50%       34.000000
# 75%       39.000000
# max       72.000000

# %%
# Histograma de la variable "price"
plt.figure(figsize=(12, 6))
sns.histplot(items['EDAD'], kde=True, bins=20)
plt.title('Distribución de la edad de entrada de los estudiantes de maestría')
plt.xlabel("Edad de entrada")
plt.show()

# Boxplot de la distribucion para cada variable numerica horizontal
plt.figure(figsize=(12, 6))
sns.boxplot(data=items, x='EDAD', color='skyblue', showmeans=True, orient='h')
plt.title('Boxplot de la edad de entrada de los estudiantes de maestría')
plt.xlabel("Edad de entrada")
plt.show()

# %%
edad_salida = info_matriculados.groupby('CODIGO_ESTUDIANTE_ANON')["EDAD"].max().reset_index()

# %%
edad_salida.describe(percentiles=[0.05, 0.25, 0.5, 0.75, 0.95, 0.99])
# Out:
#                EDAD
# count  21190.000000
# mean      34.994384
# std       14.971851
# min        0.000000
# 5%        25.000000
# 25%       30.000000
# 50%       34.000000
# 75%       39.000000
# 95%       49.000000
# 99%       56.000000
# max     1934.000000

# %%
# Cálculos para un umbral de detección de outliers
q1 = edad_salida["EDAD"].quantile(0.10)
q3 = edad_salida["EDAD"].quantile(0.90)
iqr = q3 - q1
items2 = edad_salida[edad_salida["EDAD"] <= (q3 + 1.5 * iqr)]

# %%
items2.describe()
# Out:
#                EDAD
# count  21183.000000
# mean      34.890809
# std        7.293406
# min        0.000000
# 25%       30.000000
# 50%       34.000000
# 75%       39.000000
# max       72.000000

# %%
# Histograma de la variable "price"
plt.figure(figsize=(12, 6))
sns.histplot(items2['EDAD'], kde=True, bins=20)
plt.title('Distribución de la edad de salida de los estudiantes de maestría')
plt.xlabel("Edad de salida")
plt.show()

# Boxplot de la distribucion para cada variable numerica horizontal
plt.figure(figsize=(12, 6))
sns.boxplot(data=items2, x='EDAD', color='skyblue', showmeans=True, orient='h')
plt.title('Boxplot de la edad de salida de los estudiantes de maestría')
plt.xlabel("Edad de salida")
plt.show()

# %% [markdown]
# #### Sexo

# %%
# para sexo quitamos duplicados por codigo_estudiante_anon
sexo = info_matriculados.drop_duplicates(subset='CODIGO_ESTUDIANTE_ANON')
sexo['DESCRIPCION_SEXO'].value_counts(normalize=True)
# Out:
# DESCRIPCION_SEXO
# MASCULINO     0.610237
# FEMENINO      0.389424
# No Informa    0.000339
# Name: proportion, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Proporciones de sexo
data = {
    'DESCRIPCION_SEXO': ['MASCULINO', 'FEMENINO', 'No Informa'],
    'proporcion': [0.610237, 0.389424, 0.000339]
}

# Convertir a DataFrame
df = pd.DataFrame(data)

# Calcular el número de personas en un grupo de 10
total_personas = 10
df['cantidad'] = (df['proporcion'] * total_personas).round().astype(int)

# Visualización
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x='DESCRIPCION_SEXO', y='cantidad', palette='viridis')

# Agregar títulos y etiquetas
plt.title('Distribución de Sexo en un Grupo de 10 Personas')
plt.xlabel('Descripción de Sexo')
plt.ylabel('Número de Personas')
plt.ylim(0, total_personas)  # Limitar el eje y al total de personas

# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Sector

# %%
sector = info_matriculados.drop_duplicates(subset='CODIGO_ESTUDIANTE_ANON')
sector['NOMBRE_SECTOR_EMPRESA_ESTUDIANTE'].value_counts(normalize=True)
# Out:
# NOMBRE_SECTOR_EMPRESA_ESTUDIANTE
# PRIVADO    0.663020
# PUBLICO    0.268666
# MIXTO      0.068314
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Obtener colores pastel de Seaborn
pastel_colors = sns.color_palette("pastel")

# Crear el pie chart con los colores pastel
plt.figure(figsize=(10, 10))
sector['NOMBRE_SECTOR_EMPRESA_ESTUDIANTE'].value_counts().plot.pie(autopct='%1.1f%%', colors=pastel_colors)
plt.title('Distribución del sector de empresa donde trabajan los estudiantes de maestría')
plt.ylabel('')  # Ocultar el label del eje y para que sea más limpio
plt.show()

# %% [markdown]
# #### Cargo

# %%
cargo = info_matriculados.drop_duplicates(subset='CODIGO_ESTUDIANTE_ANON')
cargo['CARGO_ESTUDIANTE'].value_counts(normalize=True)
# Out:
# CARGO_ESTUDIANTE
# INGENIERO                     0.212655
# PROFESIONAL                   0.166583
# PROFESOR                      0.140630
# COORDINADOR                   0.084599
# CONSULTOR                     0.060859
# DIRECTOR                      0.051806
# GERENTE                       0.045468
# PROGRAMADOR                   0.033699
# JEFE                          0.033196
# MEDICO                        0.018207
# PRACTICANTE                   0.017805
# INDEPENDIENTE                 0.015592
# ASOCIADO                      0.015190
# GERENTE GENERAL               0.010261
# ESTUDIANTE                    0.009858
# SUPERVISOR                    0.008148
# EJECUTIVO                     0.007243
# TECNICO                       0.007142
# DISEÑADOR                     0.006941
# SOCIO                         0.005633
# SUBDIRECTOR                   0.004627
# AUDITOR                       0.004527
# REDACTOR                      0.004024
# EDITOR                        0.003722
# SUBGERENTE                    0.003521
# REPRESENTANTE DE VENTAS       0.002414
# REPORTERO                     0.002314
# PROPIETARIO                   0.002112
# CONTRALOR                     0.002012
# CO DIRECTOR                   0.002012
# INTERVENTOR                   0.002012
# VENDEDOR                      0.002012
# VICEPRESIDENTE                0.001811
# OTRO                          0.001609
# CONTADOR                      0.001609
# INSPECTOR                     0.001408
# PRESIDENTE                    0.001207
# ANALISTA                      0.001207
# PRODUCTOR                     0.000805
# ASISTENTE DE INVESTIGACION    0.000604
# COMISIONISTA DE BOLSA         0.000604
# ASESOR                        0.000604
# ASISTENTE                     0.000604
# VICE DECANO                   0.000302
# DECANO                        0.000201
# GOBERNADOR                    0.000201
# MINISTRO                      0.000101
# VICEMINISTRO                  0.000101
# REVISOR FISCAL                0.000101
# RETIRADO                      0.000101
# Name: proportion, dtype: float64

# %%
cargos = ["INGENIERO", "PROFESIONAL", "PROFESOR", "COORDINADOR", "CONSULTOR", "DIRECTOR", "GERENTE", "PROGRAMADOR", "JEFE", "MEDICO", 
          "PRACTICANTE", "INDEPENDIENTE", "ASOCIADO", "GERENTE GENERAL"]
cargo = cargo[cargo['CARGO_ESTUDIANTE'].isin(cargos)]

# %%
# PLOT ROOM TYPE DISTRIBUTION IN THE DATASET 
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=cargo, y='CARGO_ESTUDIANTE', order=cargo['CARGO_ESTUDIANTE'].value_counts().index)
plt.title('Cantidad de estudiantes por el cargo que desempeña en su empresa')
plt.xlabel('Cargo')
plt.ylabel('Cantidad de estudiantes')

# Add value labels to the bars

for p in ax.patches:
    #ax = plt.gca()

    ax.annotate(f'{p.get_width():.0f}', (p.get_width() + 1, p.get_y() + 0.5), ha='left', va='center')

plt.show()

# %% [markdown]
# #### Estado Civil

# %%
estado_civil = info_matriculados.drop_duplicates(subset='CODIGO_ESTUDIANTE_ANON')
estado_civil['TIPO_ESTADO_CIVIL'].value_counts(normalize=True)
# Out:
# TIPO_ESTADO_CIVIL
# SOLTERO        0.790515
# CASADO         0.145540
# UNION LIBRE    0.051168
# DIVORCIADO     0.006418
# SEPARADO       0.005408
# VIUDO          0.000951
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Obtener colores pastel de Seaborn
pastel_colors = sns.color_palette("pastel")

# Función personalizada para mostrar solo los porcentajes mayores a 2%
def autopct_func(pct):
    return ('%1.1f%%' % pct) if pct > 2 else ''

# Crear el pie chart
plt.figure(figsize=(10, 10))
estado_civil_counts = estado_civil['TIPO_ESTADO_CIVIL'].value_counts()

estado_civil_counts.plot.pie(
    autopct=autopct_func,
    colors=pastel_colors,
    pctdistance=0.85,        # Ajustar la distancia de los porcentajes al centro
    labeldistance=1.2,       # Aumentar un poco la distancia de las etiquetas
    wedgeprops={'linewidth': 1, 'edgecolor': 'white'}  # Separación entre secciones
)

plt.title('Distribución del estado civil de los estudiantes de maestría')
plt.ylabel('')  # Ocultar el label del eje y para que sea más limpio
plt.show()

# %% [markdown]
# #### País/Departamento

# %%
pais = info_matriculados.drop_duplicates(subset='CODIGO_ESTUDIANTE_ANON')
pais['PAIS_RESIDENCIA_UG'].value_counts(normalize=True)
# Out:
# PAIS_RESIDENCIA_UG
# COLOMBIA          0.995304
# ESTADOS UNIDOS    0.000899
# PERU              0.000599
# ECUADOR           0.000599
# ESPAÑA            0.000450
# MEXICO            0.000400
# SUIZA             0.000250
# CANADA            0.000250
# FRANCIA           0.000200
# PAISES BAJOS      0.000150
# PANAMA            0.000100
# ALEMANIA          0.000100
# COSTA RICA        0.000100
# BOLIVIA           0.000100
# BRASIL            0.000100
# AUSTRALIA         0.000100
# PARAGUAY          0.000100
# PORTUGAL          0.000050
# VENEZUELA         0.000050
# CHILE             0.000050
# SUECIA            0.000050
# Name: proportion, dtype: float64

# %%
pais["DEPARTAMENTO_RESIDENCIA_UG"].value_counts(normalize=True)
# Out:
# DEPARTAMENTO_RESIDENCIA_UG
# BOGOTÁ, D.C.       0.825648
# CUNDINAMARCA       0.055753
# ANTIOQUIA          0.016786
# SANTANDER          0.013189
# VALLE DEL CAUCA    0.012989
#                      ...
# GUAVIARE           0.000050
# FARO               0.000050
# AREQUIPA           0.000050
# CHIHUAHUA          0.000050
# GOTALAND           0.000050
# Name: proportion, Length: 75, dtype: float64

# %% [markdown]
# ### Análisis Bivariado

# %% [markdown]
# #### Porcentaje de creditos aprobados por periodo

# %%
info_matriculados["PCA"] = info_matriculados["CREDITO_APROBADO_GLOBAL"] / info_matriculados["CREDITO_INTENTADO_GLOBAL"]
#info_matriculados["PCA_SEM"] =  info_matriculados["CREDITO_SEM_APROBADO_INSTITUCIONAL"] / info_matriculados["CREDITO_SEM_INTENTADO_INSTITUCIONAL"]

# %%
info_matriculados["PCA"].describe()
# Out:
# count    84363.000000
# mean         0.983029
# std          0.073375
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.142857
# Name: PCA, dtype: float64

# %%
# Cálculos para un umbral de detección de outliers
q1 = info_matriculados["PCA"].quantile(0.10)
q3 = info_matriculados["PCA"].quantile(0.90)
iqr = q3 - q1
items3 = info_matriculados[info_matriculados["PCA"] <= (q3 + 1.5 * iqr)]

# %%
items3["PCA"].describe()
# Out:
# count    84362.000000
# mean         0.983027
# std          0.073374
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: PCA, dtype: float64

# %%
items3 = items3[items3["PERIODO"].astype(int)>=201500]
items3 = items3[(items3["PERIODO"].str.endswith("10"))|(items3["PERIODO"].str.endswith("20"))]
items3 = items3.sort_values(by = "PERIODO")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ajustar el tamaño del gráfico
plt.figure(figsize=(16, 6))

# Crear el gráfico de líneas con marcadores en cada punto
sns.lineplot(data=items3, x='PERIODO', y='PCA', ci=None, marker='o')
#sns.lineplot(data=items3, x='PERIODO', y='PCA_SEM', ci=None, marker='o')

# Ajustar el título y los ejes
plt.title('Porcentaje de créditos aprobados por periodo')
plt.xlabel('Periodo')
plt.ylabel('Porcentaje de créditos aprobados')

# Establecer el rango del eje Y entre 0 y 100
plt.ylim(0.8, 1)



# Mostrar el gráfico
plt.show()
# Out:
# /var/folders/r5/cc3y743j5ys_g9v6b67d72jh0000gn/T/ipykernel_59586/2884814611.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=items3, x='PERIODO', y='PCA', ci=None, marker='o')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Adjust plot size
plt.figure(figsize=(16, 6))

# Line plot for the mean (default behavior)
sns.lineplot(data=items3, x='PERIODO', y='PCA', ci=None, marker='o', label='Mean', estimator=np.mean)

# Line plot for the median
sns.lineplot(data=items3, x='PERIODO', y='PCA', ci=None, marker='o', label='Median', estimator=np.median)

# Adjust title and axes
plt.title('Porcentaje de créditos aprobados por periodo')
plt.xlabel('Periodo')
plt.ylabel('Porcentaje de créditos aprobados')

# Set Y-axis range
plt.ylim(0.8, 1.01)

# Show the legend
plt.legend()

# Display the plot
plt.show()
# Out:
# /var/folders/r5/cc3y743j5ys_g9v6b67d72jh0000gn/T/ipykernel_59586/3826323413.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=items3, x='PERIODO', y='PCA', ci=None, marker='o', label='Mean', estimator=np.mean)
# /var/folders/r5/cc3y743j5ys_g9v6b67d72jh0000gn/T/ipykernel_59586/3826323413.py:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=items3, x='PERIODO', y='PCA', ci=None, marker='o', label='Median', estimator=np.median)

# %%
items3["PCA"].describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.99])
# Out:
# count    62872.000000
# mean         0.981009
# std          0.077257
# min          0.000000
# 1%           0.666667
# 5%           0.864407
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# 95%          1.000000
# 99%          1.000000
# max          1.000000
# Name: PCA, dtype: float64

# %%
#box plot of PCA
plt.figure(figsize=(12, 6))
sns.boxplot(data=items3, x='PCA', color='skyblue', showmeans=True)
plt.title('Boxplot del porcentaje de créditos aprobados')
plt.xlabel('Porcentaje de créditos aprobados')
plt.show()

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Include this line at the beginning of your notebook
# %matplotlib inline

# Ensure PERIODO is sorted
info_matriculados = info_matriculados.sort_values(by='PERIODO')

# Filter the data as per your condition
filtered_data = info_matriculados[((info_matriculados["PERIODO"].str.endswith("10"))|(info_matriculados["PERIODO"].str.endswith("20")))&(info_matriculados["PERIODO"].astype(int) >= 201500)]
filtered_data = filtered_data[filtered_data["PERIODO"] != "202420"]

# Melt the DataFrame to combine both 'PROMEDIO_GLOBAL' and 'PROMEDIO_SEM_GLOBAL' in one column
melted_data = pd.melt(filtered_data, id_vars=["PERIODO"], 
                      value_vars=["PCA"],
                      var_name="Promedio_Type", value_name="Promedio")

# Create the boxplot where both PROMEDIO_GLOBAL and PROMEDIO_SEM_GLOBAL appear in the same graph
plt.figure(figsize=(14, 8))  # Increased figure size for more space
sns.boxplot(data=melted_data, x='PERIODO', y='Promedio', hue='Promedio_Type')

# Change legend labels
handles, labels = plt.gca().get_legend_handles_labels()
new_labels = ["PCA"]

# Move the legend to a better position
plt.legend(handles, new_labels, title='Tipo de Promedio', loc='upper left', bbox_to_anchor=(1, 1))

# Display the plot
plt.title('Boxplot de Promedios por Período')
plt.xlabel('Período')
plt.ylabel('Promedio')
plt.tight_layout()  # Adjust layout to make space for the legend
plt.show()

# %% [markdown]
# #### Tipo de financiación por periodo

# %%
info_matriculados["TIPO_SECCION"].value_counts(normalize=True)
# Out:
# TIPO_SECCION
# CAJA Y BANCOS                                    0.662893
# BECAS Y PRESTAMOS EXTERNOS                       0.157375
# BECAS INTERNAS                                   0.125144
# DESCUENTOS                                       0.022976
# UTILIZACIÓN RECURSOS RECIBIDOS POR ANTICIPADO    0.015218
# PRESTAMOS REEMBOLSABLES                          0.012426
# OTROS INGRESOS                                   0.002768
# PRESTAMOS CONDONABLES                            0.001069
# DEVOLUCIONES                                     0.000083
# SIN INFORMACIÓN                                  0.000024
# MATRICULAS                                       0.000024
# Name: proportion, dtype: float64

# %%
info_matriculados["CLASIFICACION_BECAS"].value_counts(normalize=True)
# Out:
# CLASIFICACION_BECAS
# OTRAS FORMAS DE PAGO    0.717481
# BECAS EXTERNAS          0.157375
# BECAS INTERNAS          0.125144
# Name: proportion, dtype: float64

# %%
# mapa de calor clasificacion_becas vs periodo y que el valor sea el conteo de codigo_estudiante_anon

# Crear una tabla pivote con 'CLASIFICACION_BECAS' en las filas y 'PERIODO' en las columnas
pivot_table = items3.pivot_table(index='CLASIFICACION_BECAS', columns='PERIODO', values='CODIGO_ESTUDIANTE_ANON', aggfunc='count')

# Crear el heatmap
plt.figure(figsize=(16, 6))
sns.heatmap(pivot_table, cmap='viridis', annot=True, fmt='g')
plt.title('Heatmap del tipo de financiación por periodo')
plt.xlabel('Periodo')
plt.ylabel('Tipo de financiación')
plt.show()

# %%
info_matriculados["TIPO_BECA"].value_counts(normalize=True)
# Out:
# TIPO_BECA
# OTRAS FORMAS DE PAGO                                    0.717481
# BECAS Y PRESTAMOS EXTERNOS                              0.157375
# BECA FACULTADES                                         0.058675
# BECA MAESTRIA BEPS                                      0.017262
# BECA MAESTR?A BEPS                                      0.014208
# BECA FRANCISCO PIZANO BRIGARD                           0.013805
# BECAS INTERCAMBIO MAESTR?A                              0.003909
# BECA MDP POTENCIA PACIFICO                              0.003267
# ASISTENCIA GRADUADA MAESTRIA                            0.003136
# BECA CENTRO ESPA?OL MAESTRIA                            0.003077
# BECA MOVILIDAD INTERNACIONAL MAESTRIA                   0.001972
# FONDO MAESTRIA UAF VAMOS JUNTOS                         0.001568
# BECA TRAVESIAS REGIONALES MAESTRIA                      0.000772
# BECA CONVENIO MINUTO DE DIOS                            0.000713
# BECA CONVENIO MINUTO DE DIOS MAESTRIA                   0.000487
# BECA GABRIEL VEGA LARA MAESTR                           0.000273
# FONDO DE APOYO PARA ESTUDIANTES DE MAESTRIA             0.000226
# BECA LIDER-ANDES MAESTRIA CONS                          0.000226
# BECA GRETEL WERNHER MAESTRIA                            0.000226
# BECA INNOVACION PERIODISMO DIGITAL                      0.000202
# BECA CEGA MAESTRIA EGOB                                 0.000166
# BECAS L?DERES CAMBIO SOSTENIB                           0.000154
# BECA MAESTR?A ECONOM?A PEG L                            0.000131
# BECA TRADICIONAL POSGRADOS MEDICINA FEGVL               0.000107
# BECA DE EXCELENCIA – EDUARDO ALVAREZ CORREA-MAESTRIA    0.000095
# FEGVL BECA REGIONAL                                     0.000095
# BECA TRAVES?AS REGIONALES MA                            0.000095
# BECAS LIDERES CAMBIO SOSTENIBILIDAD                     0.000083
# FONDO NEXSYS MAESTRIA                                   0.000059
# BECA EXTENSI?N                                          0.000036
# BECA INNOVACI?N PERIODISMO DI                           0.000036
# BECA GRETEL WERNHER MA                                  0.000024
# BECA GABRIEL VEGA LARA DOCT                             0.000024
# BECA DOCTORADO                                          0.000012
# BECA DE RENDIMIENTO ACADEMICO                           0.000012
# BECA PENDIENTE ESPECIAL MA                              0.000012
# Name: proportion, dtype: float64

# %% [markdown]
# ### Análisis Multivariado

# %% [markdown]
# #### PGA, PS vs. periodo

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Include this line at the beginning of your notebook
# %matplotlib inline

# Ensure PERIODO is sorted
info_matriculados = info_matriculados.sort_values(by='PERIODO')

# Filter the data as per your condition
filtered_data = info_matriculados[((info_matriculados["PERIODO"].str.endswith("10"))|(info_matriculados["PERIODO"].str.endswith("20")))&(info_matriculados["PERIODO"].astype(int) >= 201500)]
filtered_data = filtered_data[filtered_data["PERIODO"] != "202420"]

# Melt the DataFrame to combine both 'PROMEDIO_GLOBAL' and 'PROMEDIO_SEM_GLOBAL' in one column
melted_data = pd.melt(filtered_data, id_vars=["PERIODO"], 
                      value_vars=["PROMEDIO_GLOBAL", "PROMEDIO_SEM_GLOBAL"],
                      var_name="Promedio_Type", value_name="Promedio")

# Create the boxplot where both PROMEDIO_GLOBAL and PROMEDIO_SEM_GLOBAL appear in the same graph
plt.figure(figsize=(14, 8))  # Increased figure size for more space
sns.boxplot(data=melted_data, x='PERIODO', y='Promedio', hue='Promedio_Type')

# Change legend labels
handles, labels = plt.gca().get_legend_handles_labels()
new_labels = ["Promedio Global", "Promedio Semestral"]

# Move the legend to a better position
plt.legend(handles, new_labels, title='Tipo de Promedio', loc='upper left', bbox_to_anchor=(1, 1))

# Display the plot
plt.title('Boxplot de Promedios por Período')
plt.xlabel('Período')
plt.ylabel('Promedio')
plt.tight_layout()  # Adjust layout to make space for the legend
plt.show()

# %% [markdown]
# #### Correlación variables numéricas

# %%
copia = info_matriculados.copy()
copia["PCA_SEM"] = copia["CREDITO_SEM_APROBADO_INSTITUCIONAL"] / copia["CREDITO_SEM_INTENTADO_INSTITUCIONAL"]

# %%
copia.rename(columns = {"PROMEDIO_SEM_GLOBAL":"PROMEDIO SEMESTRAL", "PCA_SEM": "% CREDITOS APROBADOS SEMESTRAL", "PCA":"% CREDITOS APROBADOS",
                        "PROMEDIO_GLOBAL":"PROMEDIO GLOBAL"}, inplace = True)
copia.drop(columns={"CREDITO_SEM_APROBADO_INSTITUCIONAL", "CREDITO_SEM_INTENTADO_INSTITUCIONAL", "CREDITO_APROBADO_GLOBAL", "CREDITO_INTENTADO_GLOBAL"}, inplace = True)

# %%
# correlation (heat map) OF NUMERIC VARIABLES
import matplotlib.pyplot as plt
import seaborn as sns

# Select only the numeric columns
numeric_columns = copia.select_dtypes(include='number')

# Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Heatmap de la correlación de las variables numéricas')
plt.show()

# %% [markdown]
# ### Calidad de los datos

# %%
# bar graph with the percentage of nulls in each column
import matplotlib.pyplot as plt
import seaborn as sns


# Calculate the percentage of missing values in each column
missing_percentage = info_matriculados.isnull().mean() * 100

# Drop columns with no missing values
missing_percentage = missing_percentage.dropna()

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x=missing_percentage, y=missing_percentage.index, palette='viridis')
plt.title('Porcentaje de valores faltantes en cada columna')
plt.xlabel('Porcentaje de valores faltantes')
plt.ylabel('Columna')
plt.show()

# %%
info_matriculados["PAIS_RESIDENCIA_UG"].unique()
# Out:
# array(['COLOMBIA', None, 'ECUADOR', 'PAISES BAJOS', nan, 'PERU', 'ESPAÑA',
#        'PANAMA', 'VENEZUELA', 'ESTADOS UNIDOS', 'ALEMANIA', 'AUSTRALIA',
#        'BOLIVIA', 'COSTA RICA', 'SUIZA', 'CHILE', 'MEXICO', 'PORTUGAL',
#        'FRANCIA', 'CANADA', 'SUECIA', 'BRASIL', 'PARAGUAY'], dtype=object)

# %%
info_matriculados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 90352 entries, 24394 to 90351
# Data columns (total 32 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   PERIODO                              90352 non-null  object
#  1   CODIGO_ESTUDIANTE_ANON               90352 non-null  object
#  2   EDAD                                 90352 non-null  float64
#  3   TIPO_ESTADO_CIVIL                    69761 non-null  object
#  4   NIVEL_PROGRAMA_1                     90352 non-null  object
#  5   FACULTAD_PROGRAMA_1                  90352 non-null  object
#  6   DEPARTAMENTO_PROGRAMA_1              89686 non-null  object
#  7   PROGRAMA_1                           90352 non-null  object
#  8   DESC_ESTADO_ACADEMICO                90141 non-null  object
#  9   CREDITO_SEM_INTENTADO_INSTITUCIONAL  84460 non-null  float64
#  10  CREDITO_SEM_APROBADO_INSTITUCIONAL   84460 non-null  float64
#  11  PROMEDIO_SEM_GLOBAL                  84402 non-null  float64
#  12  CREDITO_INTENTADO_GLOBAL             84460 non-null  float64
#  13  CREDITO_APROBADO_GLOBAL              84460 non-null  float64
#  14  PROMEDIO_GLOBAL                      84460 non-null  float64
#  15  TIPO_SECCION                         84175 non-null  object
#  16  CLASIFICACION_BECAS                  84175 non-null  object
#  17  TIPO_BECA                            84175 non-null  object
#  18  DESCRIPCION_SEXO                     89641 non-null  object
#  19  ESTRATO                              3 non-null      object
#  20  TIPO_VIVIENDA                        3 non-null      object
#  21  PERTENECE_MINORIA_ETNICA             47 non-null     object
#  22  SISBEN                               3 non-null      object
#  23  PUN_SISBEN                           2 non-null      object
#  24  NOMBRE_SECTOR_EMPRESA_ESTUDIANTE     56777 non-null  object
#  25  CARGO_ESTUDIANTE                     43581 non-null  object
#  26  FECHA_GRADO_PS                       84259 non-null  datetime64[ns]
#  27  PORCENTAJE_TIEMPO_PARA_ESTUDIO       69801 non-null  object
#  28  CIUDAD_RESIDENCIA_UG                 86667 non-null  object
#  29  DEPARTAMENTO_RESIDENCIA_UG           86667 non-null  object
#  30  PAIS_RESIDENCIA_UG                   86667 non-null  object
#  31  PCA                                  84363 non-null  float64
# dtypes: datetime64[ns](1), float64(8), object(23)
# memory usage: 22.7+ MB

# %%
info_matriculados.describe()
# Out:
#                EDAD  CREDITO_SEM_INTENTADO_INSTITUCIONAL
# count  90352.000000                         84460.000000  \
# mean      35.659399                             7.051829
# min        0.000000                             0.000000
# 25%       31.000000                             4.000000
# 50%       35.000000                             8.000000
# 75%       40.000000                            10.000000
# max     1934.000000                            21.000000
# std        9.553755                             3.658363
#
#        CREDITO_SEM_APROBADO_INSTITUCIONAL  PROMEDIO_SEM_GLOBAL
# count                        84460.000000         84402.000000  \
# mean                             6.914255             3.843458
# min                              0.000000             0.000000
# 25%                              4.000000             3.980000
# 50%                              8.000000             4.330000
# 75%                             10.000000             4.580000
# max                             21.000000             5.000000
# std                              3.713905             1.419318
#
#        CREDITO_INTENTADO_GLOBAL  CREDITO_APROBADO_GLOBAL  PROMEDIO_GLOBAL
# count              84460.000000             84460.000000     84460.000000  \
# mean                  26.550148                26.090771         4.248004
# min                    0.000000                 0.000000         0.000000
# 25%                   16.000000                16.000000         4.100000
# 50%                   26.000000                26.000000         4.320000
# 75%                   36.000000                36.000000         4.510000
# max                  158.000000               158.000000         5.000000
# std                   13.787304                13.522738         0.522812
#
#                       FECHA_GRADO_PS           PCA
# count                          84259  84363.000000
# mean   2013-03-28 23:20:24.125612288      0.983029
# min              1966-07-14 00:00:00      0.000000
# 25%              2009-10-17 00:00:00      1.000000
# 50%              2014-03-28 00:00:00      1.000000
# 75%              2017-10-12 00:00:00      1.000000
# max              2025-10-27 00:00:00      1.142857
# std                              NaN      0.073375

# %%
NUM = 0
NUM2 = 0
NUM3 = 0
NUM4 = 0
for index, row in info_matriculados.iterrows():
    if row["CREDITO_INTENTADO_GLOBAL"] < row["CREDITO_APROBADO_GLOBAL"]:
        NUM+=1
    if row["CREDITO_SEM_INTENTADO_INSTITUCIONAL"] < row["CREDITO_SEM_APROBADO_INSTITUCIONAL"]:
        NUM2+=1
    if row["PCA"] >1:
        NUM3 += 1
    if row["EDAD"] >80:
        NUM4 += 1
        print(row['EDAD'])
    


print (NUM, NUM2, NUM3, NUM4)
# Out:
# 1934.0
# 124.0
# 124.0
# 124.0
# 1 1 1 4
